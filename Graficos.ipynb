# %% [markdown]
# Modelos Graficos

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array = np.arange(0, 10, 0.01)
plt.plot(array, array**2)

# %%
array = np.arange(0, 10, 0.01)

plt.style.use('classic')

plt.plot(array, array**2)
